# %% [markdown]
# **Input

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
PATH_DATA = '../mydata/'

# %%
df = pd.read_csv("C:/Users/aldian/Downloads/food_delivery_datasets.csv")

# %%
df
# Out:
#         order_id  voucher_amount                   date_time  eta_seconds  \
# 0     FOOD-10455               0  2018-08-12T20:35:08.001006         1800
# 1     FOOD-10985               0  2018-09-23T17:44:12.243273         2173
# 2     FOOD-10911               0  2018-09-19T18:08:09.387991         1418
# 3     FOOD-10932               0  2018-09-21T01:24:35.272499         1903
# 4     FOOD-10961               0  2018-09-22T17:57:45.523161         1716
# ...          ...             ...                         ...          ...
# 1071  FOOD-10921               0  2018-09-20T15:01:52.152828          900
# 1072  FOOD-10265            5000  2018-07-26T14:43:23.655294         1579
# 1073  FOOD-10534               0  2018-08-21T20:10:59.283185         2606
# 1074  FOOD-10158               0  2018-07-16T14:42:23.214427         2428
# 1075  FOOD-10770               0  2018-09-11T14:18:19.494258         1547
#
#       food_price  cust_id  rating  delivery_fee   resto_id     status  \
# ...

# %%
type(df['voucher_amount'])
# Out:
# pandas.core.series.Series

# %%
group_status = df.groupby('status')
group_status['status'].size()
# Out:
# status
# Cancelled    195
# Completed    881
# Name: status, dtype: int64

# %%
df = df[df.status == 'Completed']
df.reset_index(drop=True)
# Out:
#        order_id  voucher_amount                   date_time  eta_seconds  \
# 0    FOOD-10455               0  2018-08-12T20:35:08.001006         1800
# 1    FOOD-10985               0  2018-09-23T17:44:12.243273         2173
# 2    FOOD-10911               0  2018-09-19T18:08:09.387991         1418
# 3    FOOD-10932               0  2018-09-21T01:24:35.272499         1903
# 4    FOOD-10961               0  2018-09-22T17:57:45.523161         1716
# ..          ...             ...                         ...          ...
# 876  FOOD-10921               0  2018-09-20T15:01:52.152828          900
# 877  FOOD-10265            5000  2018-07-26T14:43:23.655294         1579
# 878  FOOD-10534               0  2018-08-21T20:10:59.283185         2606
# 879  FOOD-10158               0  2018-07-16T14:42:23.214427         2428
# 880  FOOD-10770               0  2018-09-11T14:18:19.494258         1547
#
#      food_price  cust_id  rating  delivery_fee   resto_id     status  \
# ...

# %%
df['voucher_amount'].shape
# Out:
# (881,)

# %%
df_ABOVE_5000 = df[df["voucher_amount"] > 5000]
df_ABOVE_5000.head()
# Out:
#        order_id  voucher_amount                   date_time  eta_seconds  \
# 8    FOOD-10342           10000  2018-08-03T13:58:54.286742         1265
# 31   FOOD-10410           10000  2018-08-09T20:06:09.394736         1074
# 44   FOOD-10292           10000  2018-07-29T00:59:09.189530         1458
# 137  FOOD-10743           10000  2018-09-09T13:18:17.314514         1433
# 151  FOOD-11011           25000  2018-09-25T17:24:33.355489         2890
#
#      food_price  cust_id  rating  delivery_fee   resto_id     status  \
# 8         37500   304856     5.0             0  742670531  Completed
# 31        32800   588886     5.0             0  742715861  Completed
# 44        53300   316834     5.0          2000  742676756  Completed
# 137       54700   845548     5.0             0  742703390  Completed
# 151      110900  1081809     NaN             0  742527751  Completed
#
#      random_id
# 8     0.373261
# 31    0.455108
# 44    0.603163
# 137   0.316185
# 151   0.704929

# %%
df['voucher_amount']>5000
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1071    False
# 1072    False
# 1073    False
# 1074    False
# 1075    False
# Name: voucher_amount, Length: 881, dtype: bool

# %%
df_ABOVE_5000.shape
# Out:
# (38, 11)
